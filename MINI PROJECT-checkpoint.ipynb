# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # IMPORT THE DATA

# %%
weather=pd.read_csv('C:/Users/Admin/Downloads/weather.csv')

# %%
weather
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
weather=weather.rename(columns={'Date.Full':'DATE'})

# %%
weather.index=weather.DATE

# %%
weather
# Out:
#             Data.Precipitation        DATE  Date.Month  Date.Week of  \
# DATE
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.16  2016-01-03           1             3
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.01  2016-01-03           1             3
# ...                        ...         ...         ...           ...
# 2017-01-01                0.08  2017-01-01           1             1
# 2017-01-01                0.00  2017-01-01           1             1
# 2017-01-01                0.00  2017-01-01           1             1
# 2017-01-01                0.06  2017-01-01           1             1
# 2017-01-01                0.10  2017-01-01           1             1
#
#             Date.Year Station.City Station.Code Station.Location  \
# DATE
# ...

# %%
del weather["Station.Code"]

# %%
weather.head()
# Out:
#             Data.Precipitation        DATE  Date.Month  Date.Week of  \
# DATE
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.16  2016-01-03           1             3
# 2016-01-03                0.00  2016-01-03           1             3
# 2016-01-03                0.01  2016-01-03           1             3
#
#             Date.Year Station.City Station.Location Station.State  \
# DATE
# 2016-01-03       2016   Birmingham   Birmingham, AL       Alabama
# 2016-01-03       2016   Huntsville   Huntsville, AL       Alabama
# 2016-01-03       2016       Mobile       Mobile, AL       Alabama
# 2016-01-03       2016   Montgomery   Montgomery, AL       Alabama
# 2016-01-03       2016    Anchorage    Anchorage, AK        Alaska
#
#             Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# DATE
# ...

# %% [markdown]
# # MEAN OF THE DATA

# %%
weather.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11312\718641550.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   weather.mean()
# Data.Precipitation              0.579090
# Date.Month                      6.343128
# Date.Week of                   15.650242
# Date.Year                    2016.018933
# Data.Temperature.Avg Temp      56.089112
# Data.Temperature.Max Temp      66.042406
# Data.Temperature.Min Temp      45.642716
# Data.Wind.Direction            18.791316
# Data.Wind.Speed                 6.329820
# dtype: float64

# %% [markdown]
# # MEDIAN OF THE DATA

# %%
weather.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11312\1621014260.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   weather.median()
# Data.Precipitation              0.19
# Date.Month                      6.00
# Date.Week of                   16.00
# Date.Year                    2016.00
# Data.Temperature.Avg Temp      58.00
# Data.Temperature.Max Temp      68.00
# Data.Temperature.Min Temp      47.00
# Data.Wind.Direction            19.00
# Data.Wind.Speed                 5.94
# dtype: float64

# %% [markdown]
# # MODE OF THE DATA

# %%
weather.mode()
# Out:
#      Data.Precipitation        DATE  Date.Month  Date.Week of  Date.Year  \
# 0                   0.0  2016-03-06         1.0           3.0     2016.0
# 1                   NaN  2016-04-03         NaN           NaN        NaN
# 2                   NaN  2016-05-01         NaN           NaN        NaN
# 3                   NaN  2016-05-08         NaN           NaN        NaN
# 4                   NaN  2016-05-15         NaN           NaN        NaN
# ..                  ...         ...         ...           ...        ...
# 303                 NaN         NaN         NaN           NaN        NaN
# 304                 NaN         NaN         NaN           NaN        NaN
# 305                 NaN         NaN         NaN           NaN        NaN
# 306                 NaN         NaN         NaN           NaN        NaN
# 307                 NaN         NaN         NaN           NaN        NaN
#
#     Station.City       Station.Location Station.State  \
# ...

# %% [markdown]
# # RANGE

# %%
max(weather["Data.Precipitation"])
# Out:
# 20.89

# %%
min(weather["Data.Precipitation"])
# Out:
# 0.0

# %% [markdown]
# # QUANTILE VALUES

# %%
quantile_values=[weather["Data.Precipitation"].quantile(0),
                 weather["Data.Precipitation"].quantile(0.25),
                 weather["Data.Precipitation"].quantile(0.50),
                 weather["Data.Precipitation"].quantile(0.75),
                 weather["Data.Precipitation"].quantile(1)]

# %%
quantile_values
# Out:
# [0.0, 0.0, 0.19, 0.75, 20.89]

# %% [markdown]
# # DESCRIBE()

# %%
weather["Data.Precipitation"].describe()
# Out:
# count    16743.000000
# mean         0.579090
# std          0.988057
# min          0.000000
# 25%          0.000000
# 50%          0.190000
# 75%          0.750000
# max         20.890000
# Name: Data.Precipitation, dtype: float64

# %% [markdown]
# # INTERQUARTILE RANGE

# %%
weather["Data.Precipitation"].quantile(0.75) - weather["Data.Precipitation"].quantile(0.25)
# Out:
# 0.75

# %% [markdown]
# # BOX PLOT
# VARIANCE

# %%
(weather["Data.Precipitation"]).var()
# Out:
# 0.9762569493653824

# %%
x=weather.iloc[:,0].values.reshape(-1,1)
y=weather.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[0.  ],
#        [0.  ],
#        [0.16],
#        ...,
#        [0.  ],
#        [0.06],
#        [0.1 ]])

# %%
y
# Out:
# array([[ 4.33],
#        [ 3.86],
#        [ 9.73],
#        ...,
#        [ 1.65],
#        [18.16],
#        [ 7.51]])

# %%
plt.scatter(x,y)
plt.xlabel('Date.Month')
plt.ylabel('Date.Year')
plt.show()
